# %% [markdown]
# https://vishalmnemonic.github.io/_posts/2018-11-09-DC13/
#
# https://bokeh.pydata.org/en/0.10.0/docs/user_guide/interaction.html
#
# http://geo.holoviews.org/Working_with_Bokeh.html
#
# https://towardsdatascience.com/a-complete-guide-to-an-interactive-geographical-map-using-python-f4c5197e23e0
#
# https://www.kaggle.com/gjdevincentis/bokeh-hovertip-school-map
#
# https://medium.com/domthoms-data-sci-adventures/rats-in-the-city-pt-3-choropleth-map-56f772d5f644
#
# https://gist.github.com/dthoma8/6a6facda021ed7b4281967ab56d602b5
#
# https://github.com/bokeh/bokeh/issues/7007
#
# https://stackoverflow.com/questions/47225484/get-the-attributes-of-the-selected-item-in-a-geojsondatasource
#
# https://stackoverflow.com/questions/47871398/how-to-change-data-source-from-select-bokeh
#
# https://stackoverflow.com/questions/56480706/python-how-to-update-bokeh-patches-field
#
# https://automating-gis-processes.github.io/2017/lessons/L5/advanced-bokeh.html
#
# https://github.com/bokeh/bokeh/issues/7007
#
# http://www-personal.umich.edu/~scunchen/pynotebook/bokeh.html
#
# https://github.com/CartoDB/basemap-styles
#
# https://georgetsilva.github.io/posts/mapping-points-with-folium/
#
# https://www.rbtechblog.com/blog/deploy_bokeh_app
#
# http://bokeh.pydata.org/en/latest/docs/user_guide/server.html
#
# https://bokeh.pydata.org/en/latest/docs/reference/io.html
#
# https://automating-gis-processes.github.io/CSC18/lessons/L5/interactive-map-bokeh.html
#
# https://automating-gis-processes.github.io/CSC18/lessons/L5/advanced-bokeh.html
#
# https://automating-gis-processes.github.io/CSC18/lessons/L6/zonal-statistics.html
#
# https://automating-gis-processes.github.io/CSC18/lessons/L5/share-on-github.html
#
# https://automating-gis-processes.github.io/2016/Lesson5-interactive-map-bokeh.html
#
# https://bokeh.pydata.org/en/latest/docs/user_guide/geo.html

# %%
from bokeh.io import show, output_notebook, output_file
from bokeh.models import (
    GeoJSONDataSource,
    HoverTool,
    LinearColorMapper
)
from bokeh.plotting import figure
from bokeh.palettes import Viridis6
from bokeh.tile_providers import CARTODBPOSITRON
from bokeh.models.widgets import CheckboxGroup, Slider, RangeSlider, Tabs
import json
import collections

import bokeh

from bokeh.io import show, output_notebook, push_notebook
from bokeh.plotting import figure

from bokeh.models import CategoricalColorMapper, HoverTool, ColumnDataSource, Panel
from bokeh.models.widgets import CheckboxGroup, Slider, RangeSlider, Tabs

from bokeh.layouts import column, row, WidgetBox
from bokeh.palettes import Category20_16

from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application


import pandas as pd
import numpy as np
from numpy.random import random

from bokeh.core.properties import Instance, Dict, JSON, Any

from bokeh import events
from bokeh.models import (Select, Column, Row, ColumnDataSource, HoverTool, 
                          Range1d, LinearAxis, GeoJSONDataSource, ColumnarDataSource)
from bokeh.plotting import figure
from bokeh.io import curdoc

import os
import datetime
from collections import OrderedDict
from bokeh.models.widgets import Select
from numpy.random import random, normal, lognormal

from bokeh import events
from bokeh.models import (Select, Column, Row, ColumnDataSource, HoverTool, 
                          Range1d, LinearAxis, GeoJSONDataSource, ColumnarDataSource)

from bokeh.models import CheckboxGroup, RadioGroup, Toggle

from bokeh.palettes import Blues9, OrRd9

from bokeh.models import (
    BasicTicker, ColumnDataSource, ColorBar,
    ColorMapper, CustomJS, Div,
    HBar, HoverTool, LinearColorMapper,
    LogColorMapper, MultiSelect, PrintfTickFormatter,
    Select
)

from bokeh.themes import Theme
import yaml
from bokeh.tile_providers import get_provider, Vendors
# Out:
# BokehDeprecationWarning: CARTODBPOSITRON was deprecated in Bokeh 1.1.0 and will be removed, use get_provider(Vendors.CARTODBPOSITRON) instead.

# %%
with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
    chi_json = json.load(json_file)

zipcodes = collections.defaultdict()
for zip_idx in range(len(chi_json['features'])):
    zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx

# %%
select = Select(title="Option:", value="foo", options=["foo", "bar", "baz", "quux"])

# %%
output_notebook()
show(select)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1010">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="211a2078-a76e-482e-b159-4844ac7ed050"></div>

# %%
N = 300
source = ColumnDataSource(data = {'x':random(N), 'y':random(N)})

# %%
plot = figure()
plot.circle(x = 'x', y ='y', source = source)
# Out:
# GlyphRenderer(id='1050', ...)

# %%
slider = Slider(start = 100, end = 1000, value = N, step = 10, title = 'Number of Points')

# %%
def callback(attr, old, new):
    N = slider.value
    source.data = {'x':random(N), 'y':random(N)}
slider.on_change('value', callback)

# %%
layout = column(slider, plot)

# %%
curdoc().add_root(layout)

# %% [markdown]
# https://s3.amazonaws.com/assets.datacamp.com/production/course_2244/slides/ch4_slides.pdf

# %%
def modify_doc(doc):
    N = 300
    source = ColumnDataSource(data = {'x':random(N), 'y':random(N)})

    plot = figure()
    plot.circle(x = 'x', y ='y', source = source)

    slider = Slider(start = 100, end = 1000, value = N, step = 10, title = 'Number of Points')

    def callback(attr, old, new):
        N = slider.value
        source.data = {'x':random(N), 'y':random(N)}
    slider.on_change('value', callback)

    layout = column(slider, plot)
    doc.add_root(layout)
#     curdoc().add_root(layout)

handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1066">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:63280/autoload.js?bokeh-autoload-element=1067&bokeh-absolute-url=http://localhost:63280&resources=none" id="1067"></script>

# %%
def modify_doc(doc):
    N = 100
    source = ColumnDataSource(data = {'x':random(N), 'y':random(N)})

    plot = figure()
    plot.circle(x = 'x', y ='y', source = source)

    menu = Select(options = ['uniform', 'normal', 'lognormal'], value = 'uniform', title = 'Distribution')
    

    def callback(attr, old, new):
        if menu.value == 'uniform': 
            f = random
        elif menu.value == 'normal':
            f = normal
        else:
            f = lognormal
        source.data = {'x':f(size=N), 'y':f(size = N)}
    menu.on_change('value', callback)

    layout = column(menu, plot)
    doc.add_root(layout)
#     curdoc().add_root(layout)

handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1785">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:63403/autoload.js?bokeh-autoload-element=1786&bokeh-absolute-url=http://localhost:63403&resources=none" id="1786"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot):
        for zipcode in zipcodes_to_plot:
            chi_json['features'][zipcodes[zipcode]]['properties']['color_type'] = 1
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        
        zipcodes_to_plot = [zipcode_selection.labels[i] for i in 
                            zipcode_selection.active]
        geo_source_new = make_dataset(zipcodes_to_plot)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
        TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"
        p = figure(title="Chicago", tools=TOOLS,\
                   x_axis_location=None, y_axis_location=None,\
        #            x_range=(-9780000, -9745000), y_range=(5120000, 5170000),\
        #            x_axis_type="mercator", y_axis_type="mercator"\
                  )
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
                  line_color='white', line_width=0.5, source=geo_source)
#         hover = p.select_one(HoverTool)
#         hover.point_policy = "follow_mouse"
#         hover.tooltips = [("Zipcode", "@ZIP")]
        hover = HoverTool(tooltips=[('Zipcode', '@ZIP'),
#                             ('Delay', '@f_interval'),
#                             ('Proportion', '@f_proportion')
                        ])
        p.add_tools(hover)
        
#         p.legend.click_policy = 'hide'
    
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcode_selection = CheckboxGroup(labels=list(zipcodes), active = [0, 1])
    zipcode_selection.on_change('active', update_to)
    
    controls = WidgetBox(zipcode_selection)
    
    initial_zipcodes = [zipcode_selection.labels[i] for i in zipcode_selection.active]
        
    geo_source = make_dataset(initial_zipcodes)
    
    p = make_plot(geo_source)
    
    layout = row(controls, p)
    doc.add_root(layout)
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %% [markdown]
# radio
#
# https://stackoverflow.com/questions/43414670/cannot-get-response-from-bokeh-radiobuttongroup
#
# https://stackoverflow.com/questions/46357598/bokeh-python-how-to-interact-with-radio-buttons

# %%
def modify_doc(doc):


    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        
    idx_to_zip = collections.defaultdict()
    for zip_idx in range(len(chi_json['features'])):
        idx_to_zip[zip_idx] = chi_json['features'][zip_idx]['properties']['ZIP']
#         zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
        
    def make_dataset(zipcodes_to_plot):
        for zipcode in zipcodes_to_plot:
            chi_json['features'][zipcodes[zipcode]]['properties']['color_type'] = 1
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
    
    initial_zipcodes = ['60647']
    
    geo_source = make_dataset(initial_zipcodes)
    
    
    def update_to(source = geo_source, window = None):
        
#         zipcodes_to_plot = [zipcode_selection.labels[i] for i in 
#                             zipcode_selection.active]
        m = cb_obj.active
        geo_source_new = make_dataset(idx_to_zip[m])
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        source.trigger('change')

        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
        TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"
        p = figure(title="Chicago", tools=TOOLS,\
                   x_axis_location=None, y_axis_location=None,\
        #            x_range=(-9780000, -9745000), y_range=(5120000, 5170000),\
        #            x_axis_type="mercator", y_axis_type="mercator"\
                  )
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
                  line_color='white', line_width=0.5, source=geo_source)
#         hover = p.select_one(HoverTool)
#         hover.point_policy = "follow_mouse"
#         hover.tooltips = [("Zipcode", "@ZIP")]
        hover = HoverTool(tooltips=[('Zipcode', '@ZIP'), 
#                             ('Delay', '@f_interval'),
#                             ('Proportion', '@f_proportion')
                        ])
        p.add_tools(hover)
        
#         p.legend.click_policy = 'hide'
    
        return p
    

    
#     zipcode_selection = RadioGroup(labels=list(zipcodes))
#     zipcode_selection.on_change('active', update_to)
    
#     controls = WidgetBox(zipcode_selection)

    controls = bokeh.models.RadioGroup(labels=list(zipcodes),active=0,
                   callback=bokeh.models.CustomJS.from_py_func(update_to))
    
#     initial_zipcodes = [zipcode_selection.labels[i] for i in zipcode_selection.active]
    
#     initial_zipcodes = ['60647']
    
#     geo_source = make_dataset(initial_zipcodes)
    

    
    p = make_plot(geo_source)
    
    layout = row(controls, p)
    doc.add_root(layout)
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6521">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:64221/autoload.js?bokeh-autoload-element=6522&bokeh-absolute-url=http://localhost:64221&resources=none" id="6522"></script>

# %%
import sys
print (sys.executable)
# Out:
# /anaconda3/bin/python

# %% [markdown]
# Select area

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot):
        for zipcode in zipcodes_to_plot:
            chi_json['features'][zipcodes[zipcode]]['properties']['color_type'] = 1
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        
#         zipcodes_to_plot = [zipcode_selection.labels[i] for i in 
#                             zipcode_selection.active]
        try:
            selected = geo_source.selected['1d']['indices'][0]
        except IndexError:
            return
        geo_source_new = make_dataset(selected)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
        TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"
        p = figure(title="Chicago", tools=TOOLS,\
                   x_axis_location=None, y_axis_location=None,\
        #            x_range=(-9780000, -9745000), y_range=(5120000, 5170000),\
        #            x_axis_type="mercator", y_axis_type="mercator"\
                  )
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
                  line_color='white', line_width=0.5, source=geo_source)
#         hover = p.select_one(HoverTool)
#         hover.point_policy = "follow_mouse"
#         hover.tooltips = [("Zipcode", "@ZIP")]
        hover = HoverTool(tooltips=[('Zipcode', '@ZIP'), 
#                             ('Delay', '@f_interval'),
#                             ('Proportion', '@f_proportion')
                        ])
        p.add_tools(hover)
        
        p.on_event(events.SelectionGeometry, update_to)
        
#         p.legend.click_policy = 'hide'
    
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
#     zipcode_selection = CheckboxGroup(labels=list(zipcodes), active = [0, 1])
#     zipcode_selection.on_change('active', update_to)
    
    
#     controls = WidgetBox(zipcode_selection)
    
#     initial_zipcodes = [zipcode_selection.labels[i] for i in zipcode_selection.active]
        
    initial_zipcodes = ['60647']
    
    geo_source = make_dataset(initial_zipcodes)
    
    p = make_plot(geo_source)
    
    
    
#     layout = row(controls, p)
    layout = row(p)
    doc.add_root(layout)
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2639">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:63747/autoload.js?bokeh-autoload-element=2640&bokeh-absolute-url=http://localhost:63747&resources=none" id="2640"></script>
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=2640&bokeh-absolute-url=http://localhost:63747&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:63747', method='GET', uri='/autoload.js?bokeh-autoload-element=2640&bokeh-absolute-url=http://localhost:63747&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 26, in get
#     session = yield self.get_session()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 43, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/server/contexts.py", line 185, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/application/application.py", line 179, in initialize_document
#     h.modify_document(doc)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 134, in modify_document
#     self._func(doc)
#   File "<ipython-input-40-f69330c7c6ba>", line 75, in modify_doc
#     p = make_plot(geo_source)
#   File "<ipython-input-40-f69330c7c6ba>", line 47, in make_plot
#     p.on_event(events.SelectionGeometry, update_to)
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 37, in on_event
#     _check_callback(callback, ('event',), what='Event callback')
#   File "/anaconda3/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 21, in _check_callback
#     raise ValueError(error_msg % (", ".join(fargs), formatted_args))
# ValueError: Event callback must have signature func(event), got func(attr, old, new)
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=2640&bokeh-absolute-url=http://localhost:63747&resources=none (::1) 44.78ms

# %% [markdown]
# # Select

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        for zipcode in zipcodes_to_plot:
            chi_json['features'][zipcodes[zipcode]]['properties']['color_type'] = 1
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        
        zipcodes_to_plot = [zipcode_selection.value]
        geo_source_new = make_dataset(zipcodes_to_plot)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
#                    x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         p.add_tile(CARTODBPOSITRON)
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source)
#         hover = p.select_one(HoverTool)
#         hover.point_policy = "follow_mouse"
#         hover.tooltips = [("Zipcode", "@ZIP")]

        

#         p.grid.grid_line_color = None
        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
#                             ('Delay', '@f_interval'),
#                             ('Proportion', '@f_proportion')
                        ])
        p.add_tools(hover)
        
#         p.legend.click_policy = 'hide'
    
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcodes_sorted.sort()
    
    zipcode_selection = Select(options=zipcodes_sorted, value = zipcodes_sorted[0])
    zipcode_selection.on_change('value', update_to)
    
#     controls = WidgetBox(zipcode_selection)
    
    initial_zipcodes = [zipcodes_sorted[0]]
        
    geo_source = make_dataset(initial_zipcodes)
    
    p = make_plot(geo_source)
    
    layout = row(zipcode_selection, p)
    doc.add_root(layout)
    doc.theme = Theme(json=yaml.load(
            """ attrs:
                    Figure:
                        background_fill_color: "#DDDDDD"
                        outline_line_color: white
                        toolbar_location: above
            """
        ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1617">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:52844/autoload.js?bokeh-autoload-element=1618&bokeh-absolute-url=http://localhost:52844&resources=none" id="1618"></script>

# %%
chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist')

def modify_doc(doc):
    def make_dataset(zipcodes_to_plot):
#         max_color = 4
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
#         for zipcode in zipcodes_to_plot:
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            for zipcode_near in distances[:3]:
                if zipcode_near[0] in zipcodes:
                    chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        
        zipcodes_to_plot = zipcode_selection.value
        geo_source_new = make_dataset(zipcodes_to_plot)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
#                    x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
        p.add_tile(get_provider(Vendors.CARTODBPOSITRON))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source)
#         hover = p.select_one(HoverTool)
#         hover.point_policy = "follow_mouse"
#         hover.tooltips = [("Zipcode", "@ZIP")]

        

#         p.grid.grid_line_color = None
        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
#                             ('Delay', '@f_interval'),
#                             ('Proportion', '@f_proportion')
                        ])
        p.add_tools(hover)
        
#         p.legend.click_policy = 'hide'
    
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcodes_sorted.sort()
    
    zipcode_selection = Select(options=zipcodes_sorted, value = zipcodes_sorted[0])
    zipcode_selection.on_change('value', update_to)
    
#     controls = WidgetBox(zipcode_selection)
    
    initial_zipcodes = zipcodes_sorted[0]
        
    geo_source = make_dataset(initial_zipcodes)
    
    p = make_plot(geo_source)
    
    layout = row(zipcode_selection, p)
    doc.add_root(layout)
    doc.theme = Theme(json=yaml.load(
            """ attrs:
                    Figure:
                        background_fill_color: "#DDDDDD"
                        outline_line_color: white
                        toolbar_location: above
            """
        ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:53643/autoload.js?bokeh-autoload-element=1003&bokeh-absolute-url=http://localhost:53643&resources=none" id="1003"></script>

# %%
chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_overnight')

def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            for zipcode_near in distances[:num_neighbor]:
                if zipcode_near[0] in zipcodes:
                    chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        
        zipcodes_to_plot = zipcode_selection.value
        num_neighbor = int(num_selection.value)
        geo_source_new = make_dataset(zipcodes_to_plot, num_neighbor)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source)

        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcodes_sorted.sort()
    
    zipcode_selection = Select(options=zipcodes_sorted, value = zipcodes_sorted[0], title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = '3', title = 'Number of neareast neighbors')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
        
    initial_zipcodes = zipcodes_sorted[0]
        
    geo_source = make_dataset(initial_zipcodes, 3)
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection), p)
    doc.add_root(layout)
    doc.theme = Theme(json=yaml.load(
            """ attrs:
                    Figure:

                        outline_line_color: white
                        toolbar_location: above
            """
        ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3188">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:54999/autoload.js?bokeh-autoload-element=3189&bokeh-absolute-url=http://localhost:54999&resources=none" id="3189"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            for zipcode_near in distances[:num_neighbor]:
                if zipcode_near[0] in zipcodes:
                    chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source)

        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcodes_sorted.sort()
    
    zipcode_selection = Select(options=zipcodes_sorted, value = zipcodes_sorted[0], title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = '3', title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night'], value = 'overnight', title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    initial_zipcodes = zipcodes_sorted[0]
        
    geo_source = make_dataset(initial_zipcodes, 3, 'overnight')
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1113">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:60062/autoload.js?bokeh-autoload-element=1114&bokeh-absolute-url=http://localhost:60062&resources=none" id="1114"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            num_neighbor_count = 0
            for neighbor_idx in range(len(distances)):
                if distances[neighbor_idx][0] in zipcodes:
                    num_neighbor_count +=1
                    chi_json['features'][zipcodes[distances[neighbor_idx][0]]]['properties']['color_type'] = 1
                if num_neighbor_count == num_neighbor:
                    break
#             for zipcode_near in distances[:num_neighbor]:
#                 if zipcode_near[0] in zipcodes:
#                     chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source,
                 )

        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
        zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    zipcodes_sorted.sort()
    
    zipcode_selection = Select(options=zipcodes_sorted, value = zipcodes_sorted[0], title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = '3', title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night'], value = 'overnight', title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    initial_zipcodes = zipcodes_sorted[0]
        
    geo_source = make_dataset(initial_zipcodes, 3, 'overnight')
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2116">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:57797/autoload.js?bokeh-autoload-element=2117&bokeh-absolute-url=http://localhost:57797&resources=none" id="2117"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            num_neighbor_count = 0
            for neighbor_idx in range(len(distances)):
                if distances[neighbor_idx][0] in zipcodes:
                    num_neighbor_count +=1
                    chi_json['features'][zipcodes[distances[neighbor_idx][0]]]['properties']['color_type'] = 1
                if num_neighbor_count == num_neighbor:
                    break
#             for zipcode_near in distances[:num_neighbor]:
#                 if zipcode_near[0] in zipcodes:
#                     chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source,
                 )

        hover = HoverTool(tooltips=[('Zipcode', '@ZIP')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
#         zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    
    
    chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ 'midday')
    for zipcode in chi_zipcode_to_dist:
        if zipcode in zipcodes:
            zipcodes_sorted.append(zipcode)
    del zipcode

    
    zipcodes_sorted.sort()
    
    initial_zipcodes = zipcodes_sorted[0]
    initial_num = 3
    initial_period = 'midday'
    
    zipcode_selection = Select(options=zipcodes_sorted, value = initial_zipcodes, title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = str(initial_num), title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night'], value = initial_period, title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    
        
    geo_source = make_dataset(initial_zipcodes, initial_num, initial_period)
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2520">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:58289/autoload.js?bokeh-autoload-element=2521&bokeh-absolute-url=http://localhost:58289&resources=none" id="2521"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)
    
        for zipcode in zipcodes:
            if zipcode in chi_zipcode_to_dist:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'YES'
            else:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'NO'


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            num_neighbor_count = 0
            for neighbor_idx in range(len(distances)):
                if distances[neighbor_idx][0] in zipcodes:
                    num_neighbor_count +=1
                    chi_json['features'][zipcodes[distances[neighbor_idx][0]]]['properties']['color_type'] = 1
                if num_neighbor_count == num_neighbor:
                    break
#             for zipcode_near in distances[:num_neighbor]:
#                 if zipcode_near[0] in zipcodes:
#                     chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source,
                 )

        hover = HoverTool(tooltips=[('Zip Code', '@ZIP'),
                                    ('Has Data', '@has_data')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
#         zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    
    
    chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ 'midday')
    for zipcode in chi_zipcode_to_dist:
        if zipcode in zipcodes:
            zipcodes_sorted.append(zipcode)
    del zipcode

    
    zipcodes_sorted.sort()
    
    initial_zipcodes = zipcodes_sorted[0]
    initial_num = 3
    initial_period = 'midday'
    
    zipcode_selection = Select(options=zipcodes_sorted, value = initial_zipcodes, title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = str(initial_num), title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night'], value = initial_period, title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    
        
    geo_source = make_dataset(initial_zipcodes, initial_num, initial_period)
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1224">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:60647/autoload.js?bokeh-autoload-element=1225&bokeh-absolute-url=http://localhost:60647&resources=none" id="1225"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)
    
        for zipcode in zipcodes:
            if zipcode in chi_zipcode_to_dist:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'YES'
            else:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'NO'


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            num_neighbor_count = 0
            for neighbor_idx in range(len(distances)):
                if distances[neighbor_idx][0] in zipcodes:
                    num_neighbor_count +=1
                    chi_json['features'][zipcodes[distances[neighbor_idx][0]]]['properties']['color_type'] = 1
                if num_neighbor_count == num_neighbor:
                    break
#             for zipcode_near in distances[:num_neighbor]:
#                 if zipcode_near[0] in zipcodes:
#                     chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
        with open('chi_json_update.json', 'w') as fp:
            json.dump(chi_json, fp)
        with open(r'chi_json_update.json','r') as f:
            geo_source = GeoJSONDataSource(geojson = f.read())
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source,
                 )

        hover = HoverTool(tooltips=[('Zip Code', '@ZIP'),
                                    ('Has Data', '@has_data')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
#         zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
    with open('chi_json_update.json', 'w') as fp:
        json.dump(chi_json, fp)
    
    
    
    chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ 'midday')
    for zipcode in chi_zipcode_to_dist:
        if zipcode in zipcodes:
            zipcodes_sorted.append(zipcode)
    del zipcode

    
    zipcodes_sorted.sort()
    
    initial_zipcodes = zipcodes_sorted[0]
    initial_num = 3
    initial_period = 'midday'
    
    zipcode_selection = Select(options=zipcodes_sorted, value = initial_zipcodes, title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = str(initial_num), title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night',\
                                       'category'], value = initial_period, title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    
        
    geo_source = make_dataset(initial_zipcodes, initial_num, initial_period)
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1756">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:63715/autoload.js?bokeh-autoload-element=1757&bokeh-absolute-url=http://localhost:63715&resources=none" id="1757"></script>

# %%
def modify_doc(doc):
    def make_dataset(zipcodes_to_plot, num_neighbor, period_str):
        with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
            chi_json = json.load(json_file)
        chi_json['features'][zipcodes[zipcodes_to_plot]]['properties']['color_type'] = 2
            
#         print(zipcodes_to_plot)

        chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ period_str)
    
        for zipcode in zipcodes:
            if zipcode in chi_zipcode_to_dist:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'YES'
            else:
                chi_json['features'][zipcodes[zipcode]]['properties']['has_data'] = 'NO'


        if zipcodes_to_plot in chi_zipcode_to_dist:
            distances = chi_zipcode_to_dist[zipcodes_to_plot]
    #         print (distances)
            num_neighbor_count = 0
            for neighbor_idx in range(len(distances)):
                if distances[neighbor_idx][0] in zipcodes:
                    num_neighbor_count +=1
                    chi_json['features'][zipcodes[distances[neighbor_idx][0]]]['properties']['color_type'] = 1
                if num_neighbor_count == num_neighbor:
                    break
#             for zipcode_near in distances[:num_neighbor]:
#                 if zipcode_near[0] in zipcodes:
#                     chi_json['features'][zipcodes[zipcode_near[0]]]['properties']['color_type'] = 1
    #             print (chi_json['features'][zipcodes[zipcode_near[0]]])

#         for zip_idx in range(len(chi_json['features'])):
#             if 'color_type' not in chi_json['features'][zip_idx]['properties']:
#                 chi_json['features'][zip_idx]['properties']['color_type'] = -1
        
#         with open('chi_json_update.json', 'w') as fp:
#             json.dump(chi_json, fp)
#         with open(r'chi_json_update.json','r') as f:
#             geo_source = GeoJSONDataSource(geojson = f.read())

        # convert json to string
        geojson = json.dumps(chi_json)
        geo_source = GeoJSONDataSource(geojson = geojson)
        return geo_source
        
    
    def update_to(attr, old, new):
        geo_source_new = make_dataset(zipcode_selection.value, int(num_selection.value), period_selection.value)
#         with open('chi_json_update.json','rt') as json_file:
#             chi_new = json.load(json_file)
#         geo_source.update(geo_source_new)

        geo_source.geojson = geo_source_new.geojson
        
    def make_plot(geo_source):
        color_mapper = LinearColorMapper(palette=Viridis6)
#         color_mapper = LogColorMapper(palette=OrRd9[::-1])
#         TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
        p = figure(title="Chicago", 
#                    tools=TOOLS,\
#                    x_axis_location=None, y_axis_location=None,\
                   x_axis_type="mercator", y_axis_type="mercator",\
#                    x_range=(-9820000, -9735000), y_range=(5130000, 5160000)
#                     plot_height=1200, plot_width=1000
                  )
#         p.grid.grid_line_color = None
        p.axis.visible = False
        p.grid.grid_line_color = None
#         https://bokeh.pydata.org/en/latest/docs/reference/tile_providers.html
        p.add_tile(get_provider(Vendors.STAMEN_TERRAIN))
        p.grid.grid_line_color = None
        p.patches('xs', 'ys', fill_alpha=0.7, fill_color={'field': 'color_type', 'transform': color_mapper}, 
#                   line_color='white', line_width=0.5, 
                  source=geo_source,
                 )

        hover = HoverTool(tooltips=[('Zip Code', '@ZIP'),
                                    ('Has Data', '@has_data')
                        ])
        p.add_tools(hover)
            
        return p
    
    with open('chi-zip-code-tabulation-areas-2012.geojson','rt') as json_file:
        chi_json = json.load(json_file)
    
    zipcodes = collections.defaultdict()
    
    zipcodes_sorted = []
    
    for zip_idx in range(len(chi_json['features'])):
        zipcodes[chi_json['features'][zip_idx]['properties']['ZIP']] = zip_idx
#         zipcodes_sorted.append(chi_json['features'][zip_idx]['properties']['ZIP'])
    
#     with open('chi_json_update.json', 'w') as fp:
#         json.dump(chi_json, fp)
    
    
    
    chi_zipcode_to_dist = pd.read_pickle('chi_zipcode_to_dist_'+ 'midday')
    for zipcode in chi_zipcode_to_dist:
        if zipcode in zipcodes:
            zipcodes_sorted.append(zipcode)
    del zipcode

    
    zipcodes_sorted.sort()
    
    initial_zipcodes = zipcodes_sorted[0]
    initial_num = 3
    initial_period = 'midday'
    
    zipcode_selection = Select(options=zipcodes_sorted, value = initial_zipcodes, title = 'Zip code area')
    num_selection = Select(options=['3','4','5'], value = str(initial_num), title = 'Number of neareast neighbors')
    period_selection = Select(options=['overnight',\
                                       'morning',\
                                       'midday',\
                                       'afternoon',\
                                       'night',\
                                       'category'], value = initial_period, title = 'Period')

    
    zipcode_selection.on_change('value', update_to)
    num_selection.on_change('value', update_to)
    period_selection.on_change('value', update_to)
        
    
        
    geo_source = make_dataset(initial_zipcodes, initial_num, initial_period)
    
    p = make_plot(geo_source)
    
    layout = row(Column(zipcode_selection,num_selection, period_selection), p)
    doc.add_root(layout)
#     doc.theme = Theme(json=yaml.load(
#             """ attrs:
#                     Figure:

#                         outline_line_color: white
#                         toolbar_location: above
#             """
#         ))
    
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
output_notebook()
show(app)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1878">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:63803/autoload.js?bokeh-autoload-element=1879&bokeh-absolute-url=http://localhost:63803&resources=none" id="1879"></script>
